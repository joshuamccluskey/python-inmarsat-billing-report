# %% [markdown]
# # January FY 20 Invoice Check for FY 20 Year End Total

# %%
import pandas as pd

import re

import os

# %%
df = pd.read_csv('./FY_2020_Invoices/Janurary_2020_Invoice.csv')

df = df.fillna("")

#df.to_csv('Janurary_2020_Invoice_Totals.csv', index=False)

df
# Out:
#                                                Bill To: Unnamed: 1  \
# 0     NOAA Pacific\nFINANCIAL MANAGEMENT DIVISION 76...
# 1                                         Terms: NET 30
# 2                                     Payments by Check
# 3                                           Payable to:
# 4
# ...                                                 ...        ...
# 9380
# 9381
# 9382
# 9383
# 9384                                              Total
#
#                   Unnamed: 2                              Unnamed: 3  \
# 0
# 1                                               Due Date: 03/16/2020
# 2                                          Payments by Wire Transfer
# 3
# 4                             Account Name: Inmarsat Government Inc.
# ...                      ...                                     ...
# 9380    1/29/2020 3:21:46 PM
# 9381    1/30/2020 3:21:47 PM
# 9382    1/31/2020 3:20:40 PM
# 9383  Total for 881651477579
# 9384
#
# ...

# %%
df = pd.read_csv('Janurary_2020_Invoice_Totals.csv')
df = df.fillna("")
df = df.rename(columns={'Unnamed: 8': 'ID', 'Unnamed: 19': 'Totals'})
df = df.loc[df['ID'].str.contains('^to[a-z]*', flags=re.I, regex=True)]
df = df.reset_index(drop=True)
#df.to_csv('Janurary_2020_Invoice_Totals_Clean.csv', index=False)
df
# Out:
#     Bill To: Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0
# 1
# 2
# 3
# 4
# ..       ...        ...        ...        ...        ...        ...
# 436
# 437
# 438
# 439
# 440
#
#     Unnamed: 6 Unnamed: 7                      ID Unnamed: 9  ... Unnamed: 14  \
# 0                          Total for 881621454873             ...
# 1                          Total for 881621454875             ...
# 2                          Total for 881621454877             ...
# 3                          Total for 881621454880             ...
# 4                          Total for 881621454881             ...
# ..         ...        ...                     ...        ...  ...         ...
# 436                        Total for 881651461225             ...
# 437                        Total for 881651477444             ...
# 438                        Total for 881651477445             ...
# 439                        Total for 881651477579             ...
# ...

# %%
df = pd.read_csv('Janurary_2020_Invoice_Totals_Clean.csv')
df = df.fillna(" ")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
#df.to_csv('Janurary_2020_Invoice_Totals_Clean_Clean.csv', index=False)
df
# Out:
#     Bill To:                      ID  Totals
# 0             Total for 881621454873  $15.07
# 1             Total for 881621454875  $15.07
# 2             Total for 881621454877  $15.07
# 3             Total for 881621454880  $15.07
# 4             Total for 881621454881  $15.07
# ..       ...                     ...     ...
# 436           Total for 881651461225  $15.07
# 437           Total for 881651477444  $15.07
# 438           Total for 881651477445  $50.18
# 439           Total for 881651477579  $50.42
# 440           Total for 881651477580  $15.07
#
# [441 rows x 3 columns]

# %%
column_sum = df['Totals'].sum()
print(column_sum)
# Out:
# $15.07$15.07$15.07$15.07$15.07$15.07$15.07$15.07$15.07$15.07$15.07$62.02$53.59$15.07$15.07$15.07$15.07$83.31$15.07$15.07$15.07$42.94$30.61$29.13$15.07$49.76$32.59$19.26$31.85$15.07$15.81$9.00$20.25$15.07$15.07$41.22$15.07$15.07$15.07$78.57$39.24$79.28$79.28$15.07$15.81$81.28$157.17$78.30$22.92$15.07$15.07$43.69$61.95$15.07$15.07$77.80$15.07$15.07$37.61$33.82$15.07$29.62$35.17$31.59$28.89$26.17$26.17$27.64$26.17$25.93$27.15$48.90$15.07$15.07$24.18$62.67$26.17$15.07$29.62$15.07$25.67$27.41$15.07$44.72$49.42$15.07$22.48$15.07$15.07$16.55$79.78$15.07$15.07$15.07$15.07$108.40$40.98$15.07$15.56$53.87$15.07$39.68$22.96$41.68$31.85$42.75$15.07$38.23$15.07$15.07$206.89$46.82$15.07$45.92$37.00$15.07$47.97$83.75$114.05$79.54$15.07$15.07$24.94$15.07$15.07$43.73$15.07$106.51$15.07$15.07$15.07$15.07$15.07$15.07$15.07$15.07$15.07$15.07$15.07$15.07$15.07$15.07$15.07$15.07$15.07$15.07$15.07$15.07$15.07$15.07$30.36$15.07$15.07$15.07$76.08$78.30$15.07$15.07$26.17$33.41$15.07$33.12$30.12$35.72$49.17$40.
# ...

# %%
df = pd.read_csv('Janurary_2020_Invoice_Totals_Clean_Clean.csv')

df['Amounts'] = df['Totals'].apply(lambda x: x.split('$')[1])

df['Amounts'] = pd.to_numeric(df['Amounts'])


#df.to_csv('FY_2020_Invoice_Totals_Clean_Numbers.csv', index=False)
# Out:
# 14110.64

# %% [markdown]
# ## This total  is evidence that Janurary 2020 inovice needs to be uploaded again with the SBD data in the invoice. The year end total then needs to be redone after Januarary inovice is updated

# %%
Actual_Total = 14666.79
Difference = Actual_Total - column_sum
print(Difference)
# Out:
# 556.1500000000015
