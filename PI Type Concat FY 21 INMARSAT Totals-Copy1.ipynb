# %% [markdown]
# # FY21 Concanted PI Totals Files Collection 1 Revised

# %%
import os
import glob
import pandas as pd
os.chdir("./FY21 PI Totals")

# %%
extension = 'xlsx'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
#combine all files in the list
combined_excel = pd.concat([pd.read_excel(f) for f in all_filenames ])
#export to csv
combined_excel.to_excel( "all_data_pi_totals collection 1.xlsx", index=False)

# %%
df = pd.read_excel( "all_data_pi_totals collection 1.xlsx")
df = df.groupby(['PI']).sum()
df['FY 21 Collection 1 Totals'] = df.iloc[:, 0:14].sum(axis=1)
df.to_excel('FY 21 INMARSAT Collection 1 Totals PI Type.xlsx')
df
# Out:
#                     3 DEC'20 Amounts Due  4 Jan'21 Amounts Due  \
# PI
# Cronin                            339.91                300.91
# Cross                             191.21                175.21
# Dziak                              63.43                 63.43
# Feely                             146.23                122.98
# Johnson                          7855.43               7593.57
# Klinck                             15.44                 15.44
# McPhaden                         2354.58               2320.58
# Meinig - Dziak                     46.32                 46.32
# Meinig - Feely                     30.88                 30.88
# Meinig Chaba                       15.44                 16.94
# Meinig Former DART                207.93                220.43
# Meinig GNSS GPS                    13.79                 13.79
# Meinig SPURS2                      58.46                 58.46
# Mordy IOTAS-ITAE                  257.29                180.12
# Mordy ITAE                        541.08                623.83
# Stabeno                           360.64                358.54
# Sutton                           2316.99               2293.87
#
#                     2 NOV'20 Amounts Due  1 Oct'20 Amounts Due  \
# PI
# Cronin                            334.41                365.66
# Cross                             176.21                218.96
# Dziak                              63.43                 63.43
# Feely                             164.19                157.19
# Johnson                         10409.71               8567.85
# Klinck                             15.44                 15.44
# McPhaden                         2612.08               2530.58
# Meinig - Dziak                     46.32                 46.32
# Meinig - Feely                     30.88                 30.88
# Meinig Chaba                       15.44                 15.44
# Meinig Former DART                214.73                209.43
# Meinig GNSS GPS                    13.79                 13.79
# Meinig SPURS2                      58.46                 89.21
# Mordy IOTAS-ITAE                  189.98                190.32
# Mordy ITAE                        591.08                525.83
# Stabeno                           605.52                610.98
# Sutton                           2283.36               2391.26
#
#                     FY 21 Collection 1 Totals
# PI
# Cronin                                1340.89
# Cross                                  761.59
# Dziak                                  253.72
# Feely                                  590.59
# Johnson                              34426.56
# Klinck                                  61.76
# McPhaden                              9817.82
# Meinig - Dziak                         185.28
# Meinig - Feely                         123.52
# Meinig Chaba                            63.26
# Meinig Former DART                     852.52
# Meinig GNSS GPS                         55.16
# Meinig SPURS2                          264.59
# Mordy IOTAS-ITAE                       817.71
# Mordy ITAE                            2281.82
# Stabeno                               1935.68
# Sutton                                9285.48
