# %% [markdown]
# # FY21 Concanted PI Type Files Collection 1

# %%
import os
import glob
import pandas as pd
os.chdir("./FY 21 PI Type Collection 2")

# %%
extension = 'xlsx'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
#combine all files in the list
combined_excel = pd.concat([pd.read_excel(f) for f in all_filenames ])
#export to csv
combined_excel.to_excel( "all_data_pi_type collection 2.xlsx", index=False)

# %%
df = pd.read_excel('all_data_pi_type collection 2.xlsx')
df = df.groupby(['PI','Type']).sum()
#df = df.drop(columns=['IDs'])
df['FY 21 Collection 2 Totals'] = df.iloc[:, 0:14].sum(axis=1)
df.to_excel('FY 21 INMARSAT Collection 2 Totals PI Type.xlsx')
df
# Out:
#                                                            Apr'21 Amounts Due  \
# PI                                       Type
# Cronin                                   RUDICS                        334.16
# Cross                                    RUDICS                        173.71
# Dziak                                    Non-RUDICS                     47.99
# Feely                                    RUDICS                         93.20
# Guyton Eagle Horizon                     RUDICS VOICE                    0.00
# Johnson                                  RUDICS                       6999.08
# Klinck                                   RUDICS                         28.69
# McPhaden                                 RUDICS                       1791.78
# Meinig - Dziak                           RUDICS                         30.88
# Meinig - Dziak DEACTIVATED 4/13/2021     RUDICS                         15.44
# ...
