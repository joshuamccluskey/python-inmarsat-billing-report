# %% [markdown]
# # FY21 Concanted PI Totals Files Collection 1 Revised

# %%
import os
import glob
import pandas as pd
os.chdir("./FY 21 PI Type Collection 2")

# %%
extension = 'xlsx'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
#combine all files in the list
combined_excel = pd.concat([pd.read_excel(f) for f in all_filenames ])
#export to csv
combined_excel.to_excel( "all_data_pi_type_totals collection 2.xlsx", index=False)

# %%
df = pd.read_excel( "all_data_pi_type_totals collection 2.xlsx")
df = df.groupby(['PI']).sum()
df = df.drop(columns=['IDs'])
df['FY 21 Collection 1 Totals'] = df.iloc[:, 0:14].sum(axis=1)
df.to_excel('FY 21 INMARSAT Collection 2 Totals PI Type.xlsx')
df
# Out:
#                                           Apr'21 Amounts Due  \
# PI
# Cronin                                                334.16
# Cross                                                 173.71
# Dziak                                                  47.99
# Feely                                                  93.20
# Guyton Eagle Horizon                                    0.00
# Johnson                                              6999.08
# Klinck                                                 28.69
# McPhaden                                             1791.78
# Meinig - Dziak                                         30.88
# Meinig - Dziak DEACTIVATED 4/13/2021                   15.44
# Meinig - Feely                                         30.88
# Meinig Chaba                                           25.44
# Meinig FCOM1.0                                         15.44
# Meinig Former DART                                    227.26
# ...
